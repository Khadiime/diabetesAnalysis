# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_diabetes= pd.read_csv('diabetes_data.csv')

# %%
data_diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
missing_val_count_by_column = (X_full.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# Series([], dtype: int64)

# %%
sns.pairplot(data_diabetes,hue='Outcome',palette='Set1')

# %%
data_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import classification_report,confusion_matrix

X = data_diabetes.drop(['Outcome',],axis=1)
y = data_diabetes['Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=101)

# Creating the decision tree model
dtree_Classifier = DecisionTreeClassifier()
dtree_Classifier.fit(X_train,y_train)
predictions = dtree_Classifier.predict(X_test)
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))

dtree_Regressor = DecisionTreeRegressor()
dtree_Regressor.fit(X_train,y_train)
predictions = dtree_Regressor.predict(X_test)
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[149  53]
#  [ 35  71]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       202
#            1       0.57      0.67      0.62       106
#
#     accuracy                           0.71       308
#    macro avg       0.69      0.70      0.69       308
# weighted avg       0.73      0.71      0.72       308
#
# [[147  55]
#  [ 38  68]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76       202
#            1       0.55      0.64      0.59       106
#
#     accuracy                           0.70       308
#    macro avg       0.67      0.68      0.68       308
# weighted avg       0.71      0.70      0.70       308

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=100)
rfr.fit(X_train, y_train)
rfr_pred = rfr.predict(X_test)
print(confusion_matrix(y_test,rfc_pred))
print('\n')
print(classification_report(y_test,rfc_pred))
# Out:
# [[131  19]
#  [ 40  41]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82       150
#            1       0.68      0.51      0.58        81
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.69      0.70       231
# weighted avg       0.74      0.74      0.73       231

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(data_diabetes.columns[1:])
features
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %%
from matplotlib import pyplot
# get importance
importance_dtree_Classifier = dtree_Classifier.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.06590
# Feature: 1, Score: 0.35297
# Feature: 2, Score: 0.10988
# Feature: 3, Score: 0.07385
# Feature: 4, Score: 0.06521
# Feature: 5, Score: 0.18356
# Feature: 6, Score: 0.14861

# %%
# get importance
importance_rfc = rfc.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.06590
# Feature: 1, Score: 0.35297
# Feature: 2, Score: 0.10988
# Feature: 3, Score: 0.07385
# Feature: 4, Score: 0.06521
# Feature: 5, Score: 0.18356
# Feature: 6, Score: 0.14861

# %%
sns.heatmap(data_diabetes.corr())

# %%
# from Data analysis on Tableau Software and the heatmap above, two features are not that effective as labels, so
# in the programming below, I'll try to improve the model by removing some not that efficient labels
# in my case I chose Glucose and BMI
X.new = data_diabetes.drop(['Outcome', 'BMI','Glucose'],axis=1)
y = data_diabetes['Outcome']
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X.new, y, test_size=0.40, random_state=101)

# Creating the decision tree model
new_dtree_Classifier = DecisionTreeClassifier()
new_dtree_Classifier.fit(X_train_1,y_train_1)
new_predictions = new_dtree_Classifier.predict(X_test_1)
print(confusion_matrix(y_test_1,new_predictions))
print('\n')
print(classification_report(y_test_1,new_predictions))

rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train_1, y_train_1)
rfc_pred = rfc.predict(X_test_1)
print(confusion_matrix(y_test_1,rfc_pred))
print('\n')
print(classification_report(y_test_1,rfc_pred))
# Out:
# [[135  67]
#  [ 40  66]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.72       202
#            1       0.50      0.62      0.55       106
#
#     accuracy                           0.65       308
#    macro avg       0.63      0.65      0.63       308
# weighted avg       0.68      0.65      0.66       308
#
# [[156  46]
#  [ 49  57]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77       202
#            1       0.55      0.54      0.55       106
#
#     accuracy                           0.69       308
#    macro avg       0.66      0.66      0.66       308
# weighted avg       0.69      0.69      0.69       308

# %%
#gridsearchcv scikit-learn
